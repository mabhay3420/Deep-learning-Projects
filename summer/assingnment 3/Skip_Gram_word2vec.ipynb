# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:15, 2.03MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
thershold = 1e-5
word_counts = Counter(int_words)
total_counts = len(int_words)
freq = {word:count/total_counts for word,count in word_counts.items()}
p_drop = {word:1-np.sqrt(thershold/freq[word]) for word in word_counts}
train_words = [word for word in int_words if random.random()<(1-p_drop[word])]
# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    size = np.random.randint(1,window_size+1)
    start = idx-size if (idx-size)>0 else 0
    end = idx+size 
    target = set(words[start:idx] + words[idx+1:end+1])
    
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name = 'inputs')
    labels = tf.placeholder(tf.int32,[None,None],name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6665 0.0353 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5991 0.0178 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4842 0.0178 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6035 0.0175 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5103 0.0174 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5521 0.0175 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5499 0.0174 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5515 0.0176 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4853 0.0173 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4438 0.0179 sec/batch
# Nearest to an: multiprogramming, inimitable, discard, erects, adhd, outlived, carrie, aneurin,
# Nearest to with: lair, kak, rechargeable, warlordism, richards, agnesi, shine, becker,
# Nearest to more: mmm, holbein, famed, foundries, midgard, sensuality, playwright, cayman,
# Nearest to no: dactyl, acyl, encyclopaedia, heir, foreman, copying, damned, byzantium,
# Nearest to time: pont, jiu, pitiful, assurance, stamping, dall, tocharians, pint,
# Nearest to would: circulation, decorations, macy, kowtow, timpani, intersect, lexikon, dianne,
# Nearest to by: owing, acidity, pascua, coli, roommates, superpowers, rectus, altitudes,
# Nearest to this: donning, upsilon, ob, barrister, stardom, piles, uphold, vr,
# Nearest to articles: onomatopoeic, thrills, drawing, brooke, veneziano, xenophanes, thatched, huggins,
# Nearest to writers: utrecht, eum, malthusian, herz, balladeer, rotors, presentational, marconi,
# Nearest to pre: badly, wwe, albeniz, yetzirah, milman, kindred, coltrane, underwing,
# Nearest to smith: anglophone, salaries, untouchability, discography, vulgarity, jacob, puddle, mariner,
# Nearest to applications: equine, brock, populist, hort, auratus, cementing, petitioned, editor,
# Nearest to proposed: finances, mlas, scrimmage, dunfermline, impressionistic, wits, perl, demonstrably,
# Nearest to hold: whiteness, concealment, purchasing, remorse, wineries, amora, makeover, moonshine,
# Nearest to event: praetorian, conscious, camel, chretien, pla, baryon, yamasaki, downforce,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4757 0.0187 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3904 0.0178 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3689 0.0174 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2520 0.0177 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2057 0.0175 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1741 0.0176 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0946 0.0177 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0723 0.0174 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0364 0.0176 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9744 0.0177 sec/batch
# Nearest to an: multiprogramming, discard, form, erects, inimitable, refreshing, outlived, monarch,
# Nearest to with: lair, environments, professional, subdivided, gadsden, stripes, richards, rechargeable,
# Nearest to more: holbein, conductor, mmm, thing, fatah, hours, playwright, famed,
# Nearest to no: dactyl, heir, encyclopaedia, pair, acyl, looking, copying, minute,
# Nearest to time: around, contains, life, jim, intervenes, dall, those, aware,
# Nearest to would: circulation, decorations, intersect, macy, lexikon, must, egypt, addressed,
# Nearest to by: owing, makers, become, silver, training, sed, acidity, reduced,
# Nearest to this: piles, ob, upsilon, into, while, hindi, soul, applications,
# Nearest to articles: drawing, onomatopoeic, veneziano, thrills, brooke, marginally, peak, preclude,
# Nearest to writers: utrecht, eum, rotors, balladeer, malthusian, bias, herz, young,
# Nearest to pre: badly, acknowledge, industry, kindred, revenues, killing, excluding, studies,
# Nearest to smith: anglophone, reason, salaries, discography, transformed, jacob, affairs, perfected,
# Nearest to applications: equine, this, planning, populist, editor, commerce, hype, petitioned,
# Nearest to proposed: finances, scrimmage, mlas, perl, close, tanks, impressionistic, dunfermline,
# Nearest to hold: concealment, purchasing, whiteness, consumed, antiquity, respectful, remorse, curia,
# Nearest to event: praetorian, conscious, camel, baryon, monoxide, pla, yamasaki, etymology,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9238 0.0186 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9311 0.0174 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8889 0.0175 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8652 0.0174 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8157 0.0175 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8261 0.0177 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8036 0.0173 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7998 0.0174 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7921 0.0175 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7836 0.0175 sec/batch
# Nearest to an: multiprogramming, monarch, discard, outlived, inimitable, erects, form, polytheism,
# Nearest to with: lair, richards, environments, rechargeable, shine, subdivided, gadsden, becker,
# Nearest to more: holbein, mmm, famed, conductor, fatah, playwright, thing, midgard,
# Nearest to no: heir, encyclopaedia, dactyl, pair, copying, acyl, damned, looking,
# Nearest to time: pont, jim, around, assurance, dall, intervenes, stamping, aware,
# Nearest to would: circulation, macy, intersect, decorations, lords, manually, omitted, egypt,
# Nearest to by: owing, silver, pascua, makers, coli, bars, acidity, superpowers,
# Nearest to this: soul, piles, applications, ob, upsilon, senses, uphold, donning,
# Nearest to articles: drawing, onomatopoeic, brooke, peak, thrills, veneziano, preclude, xenophanes,
# Nearest to writers: utrecht, eum, rotors, herz, bias, acs, demonstration, balladeer,
# Nearest to pre: badly, wwe, acknowledge, kindred, conflict, revenues, manhattan, pacifistic,
# Nearest to smith: salaries, anglophone, discography, intercepted, reason, jacob, oversees, mariner,
# Nearest to applications: equine, planning, populist, this, editor, commerce, petitioned, brock,
# Nearest to proposed: finances, demonstrably, perl, wits, impressionistic, scrimmage, anthologies, phased,
# Nearest to hold: purchasing, concealment, whiteness, remorse, consumed, respectful, dome, reasonably,
# Nearest to event: conscious, praetorian, camel, baryon, monoxide, pla, relocating, etymology,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8050 0.0184 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7381 0.0173 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7411 0.0172 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7223 0.0180 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7157 0.0175 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6993 0.0176 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7213 0.0172 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7227 0.0173 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7000 0.0174 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6687 0.0172 sec/batch
# Nearest to an: multiprogramming, adhd, monarch, discard, tendencies, outlived, inimitable, polytheism,
# Nearest to with: lair, rechargeable, environments, becker, richards, shine, productivity, adorned,
# Nearest to more: holbein, mmm, famed, midgard, beneficiaries, sensuality, fatah, explores,
# Nearest to no: heir, dactyl, encyclopaedia, pair, acyl, damned, copying, byzantium,
# Nearest to time: pont, assurance, around, jim, pitiful, dall, reform, intervenes,
# Nearest to would: circulation, macy, intersect, dianne, lords, timpani, manually, outboard,
# Nearest to by: silver, altitudes, coli, surya, acidity, discontinued, owing, mons,
# Nearest to this: applications, upsilon, alloy, hindi, piles, soul, ob, concedes,
# Nearest to articles: drawing, onomatopoeic, brooke, thrills, xenophanes, peak, veneziano, preoccupation,
# Nearest to writers: utrecht, births, acs, herz, rotors, malthusian, eum, balladeer,
# Nearest to pre: wwe, badly, acknowledge, albeniz, drafts, coltrane, revenues, manhattan,
# Nearest to smith: salaries, discography, anglophone, intercepted, isis, vx, oversees, vulgarity,
# Nearest to applications: equine, planning, this, populist, brock, commerce, theirs, feed,
# Nearest to proposed: finances, demonstrably, anthologies, impressionistic, perl, scrimmage, mlas, phased,
# Nearest to hold: whiteness, remorse, purchasing, canoes, kirby, concealment, dome, silica,
# Nearest to event: conscious, praetorian, camel, pla, baryon, relocating, monoxide, yamasaki,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6553 0.0181 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6642 0.0172 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6228 0.0174 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6216 0.0177 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6459 0.0173 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6341 0.0173 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6087 0.0128 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5472 0.0172 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5129 0.0173 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4952 0.0174 sec/batch
# Nearest to an: multiprogramming, monarch, tendencies, discard, outlived, adhd, sidebar, predefined,
# Nearest to with: lair, rechargeable, shine, warlordism, environments, becker, richards, tsunami,
# Nearest to more: holbein, mmm, beneficiaries, midgard, explores, famed, rashi, erase,
# Nearest to no: heir, dactyl, pair, encyclopaedia, acyl, damned, minimally, diligence,
# Nearest to time: pont, assurance, jiu, aware, exit, intervenes, pitiful, around,
# Nearest to would: circulation, macy, outboard, intersect, dianne, leaved, manually, timpani,
# Nearest to by: silver, altitudes, surya, pascua, coli, owing, acidity, suicidal,
# Nearest to this: soul, alloy, hindi, freeing, applications, commented, constraints, what,
# Nearest to articles: drawing, onomatopoeic, brooke, xenophanes, thrills, preoccupation, veneziano, peak,
# Nearest to writers: births, utrecht, herz, acs, malthusian, legacy, balladeer, publisher,
# Nearest to pre: badly, albeniz, wwe, pacifistic, yetzirah, drafts, industry, coltrane,
# Nearest to smith: salaries, discography, isis, intercepted, anglophone, vx, vulgarity, jacob,
# Nearest to applications: equine, planning, apple, this, brock, theirs, mpeg, populist,
# Nearest to proposed: finances, demonstrably, phased, impressionistic, mlas, anthologies, austronesian, scrimmage,
# Nearest to hold: whiteness, remorse, concealment, carmakers, adjoining, retailers, kirby, purchasing,
# Nearest to event: praetorian, conscious, pla, camel, monoxide, yamasaki, relocating, baryon,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4905 0.0185 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5345 0.0173 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4506 0.0173 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5138 0.0172 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4985 0.0169 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4759 0.0171 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4591 0.0172 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4120 0.0170 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4224 0.0171 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4188 0.0172 sec/batch
# Nearest to an: multiprogramming, tendencies, discard, form, sidebar, monarch, adhd, a,
# Nearest to with: lair, becker, rechargeable, warlordism, shine, environments, arrhenius, tsunami,
# Nearest to more: beneficiaries, mmm, holbein, hydration, explores, analytical, midgard, sensuality,
# Nearest to no: dactyl, heir, pair, acyl, encyclopaedia, copying, damned, roped,
# Nearest to time: pont, jiu, assurance, aware, intervenes, exit, pitiful, tocharians,
# Nearest to would: circulation, outboard, must, macy, intersect, leaved, dianne, overbending,
# Nearest to by: surya, altitudes, silver, pascua, coli, enveloping, owing, dss,
# Nearest to this: soul, constraints, true, senses, while, hindi, what, applications,
# Nearest to articles: drawing, xenophanes, brooke, onomatopoeic, preoccupation, history, veneziano, thrills,
# Nearest to writers: births, utrecht, acs, herz, publisher, legacy, malthusian, toasted,
# Nearest to pre: albeniz, badly, pacifistic, wwe, coltrane, drafts, abounds, industry,
# Nearest to smith: discography, salaries, isis, anglophone, intercepted, jacob, vx, erlanger,
# Nearest to applications: planning, apple, equine, mainframe, research, this, systems, enable,
# Nearest to proposed: demonstrably, phased, finances, newsreader, mlas, impressionistic, austronesian, anthologies,
# Nearest to hold: remorse, carmakers, whiteness, concealment, retailers, canoes, adjoining, curia,
# Nearest to event: praetorian, conscious, pla, camel, chretien, yamasaki, monoxide, cin,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4255 0.0182 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3996 0.0172 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4156 0.0173 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3854 0.0174 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4158 0.0173 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4265 0.0174 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3763 0.0173 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3781 0.0172 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4190 0.0171 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3822 0.0172 sec/batch
# Nearest to an: multiprogramming, sums, the, form, discard, tendencies, a, monarch,
# Nearest to with: lair, shine, warlordism, rechargeable, becker, bookmarks, linebarger, richards,
# Nearest to more: beneficiaries, mmm, sensuality, hydration, holbein, analytical, explores, bubbling,
# Nearest to no: heir, dactyl, pair, pace, diligence, damned, reworkings, heian,
# Nearest to time: jiu, pont, aware, intervenes, exit, pitiful, assurance, tocharians,
# Nearest to would: circulation, must, outboard, timpani, intersect, macy, overbending, comfortably,
# Nearest to by: surya, silver, enveloping, coli, pascua, theoretic, owing, doubly,
# Nearest to this: soul, decomposing, duration, diversify, constraints, senses, placate, freeing,
# Nearest to articles: xenophanes, drawing, onomatopoeic, brooke, preoccupation, history, omission, veneziano,
# Nearest to writers: births, herz, publisher, acs, utrecht, legacy, toasted, balladeer,
# Nearest to pre: albeniz, pacifistic, drafts, wwe, badly, jealousy, acknowledge, abounds,
# Nearest to smith: discography, salaries, isis, intercepted, erlanger, vx, chicagoland, ludovic,
# Nearest to applications: planning, enable, apple, equine, systems, research, mpeg, scan,
# Nearest to proposed: finances, demonstrably, phased, mlas, austronesian, newsreader, folding, combats,
# Nearest to hold: carmakers, remorse, whiteness, retailers, canoes, concealment, micros, unaccustomed,
# Nearest to event: praetorian, conscious, pla, camel, monoxide, chretien, baryon, yamasaki,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3723 0.0184 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3986 0.0173 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3510 0.0172 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3577 0.0172 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4010 0.0171 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3717 0.0171 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3795 0.0173 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3712 0.0171 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3441 0.0176 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3287 0.0174 sec/batch
# Nearest to an: multiprogramming, sums, the, a, monarch, adhd, form, duels,
# Nearest to with: shine, warlordism, rechargeable, arrhenius, bookmarks, lair, determines, overstated,
# Nearest to more: beneficiaries, explores, sensuality, mmm, hydration, bubbling, riffing, holbein,
# Nearest to no: heir, dactyl, diligence, pair, reworkings, acyl, posed, continuity,
# Nearest to time: jiu, aware, pont, exit, assurance, intervenes, dall, pitiful,
# Nearest to would: circulation, must, lords, macy, intersect, comfortably, disgrace, overbending,
# Nearest to by: enveloping, surya, denumerable, theoretic, coli, silver, habeas, weldon,
# Nearest to this: soul, decomposing, outage, duration, hindi, diversify, discern, shikai,
# Nearest to articles: xenophanes, history, drawing, onomatopoeic, preoccupation, brooke, omission, highlanders,
# Nearest to writers: births, herz, publisher, acs, toasted, legacy, reflector, balladeer,
# Nearest to pre: albeniz, pacifistic, dnieper, jealousy, kai, tilly, abounds, ceremoniously,
# Nearest to smith: discography, salaries, isis, intercepted, chicagoland, erlanger, ludovic, tries,
# Nearest to applications: equine, enable, research, systems, planning, scan, apple, editor,
# Nearest to proposed: finances, demonstrably, folding, newsreader, combats, phased, impressionistic, mlas,
# Nearest to hold: carmakers, remorse, whiteness, concealment, canoes, retailers, devolved, policemen,
# Nearest to event: conscious, pla, praetorian, camel, yamasaki, chretien, baryon, monoxide,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3183 0.0184 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3133 0.0174 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3602 0.0172 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4043 0.0172 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4092 0.0171 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2963 0.0173 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3261 0.0172 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3383 0.0170 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2160 0.0173 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2985 0.0172 sec/batch
# Nearest to an: multiprogramming, the, a, sums, monarch, duels, form, aneurin,
# Nearest to with: shine, warlordism, arrhenius, rechargeable, overstated, determines, linebarger, bookmarks,
# Nearest to more: explores, beneficiaries, sensuality, soundness, bubbling, daerah, holbein, riffing,
# Nearest to no: heir, dactyl, aukrust, diligence, reworkings, pair, acyl, roped,
# Nearest to time: jiu, aware, pont, exit, pitiful, intercept, heliopause, assurance,
# Nearest to would: circulation, must, macy, intersect, overbending, comfortably, outboard, weakness,
# Nearest to by: denumerable, multi, enveloping, surya, silver, theoretic, habeas, weldon,
# Nearest to this: decomposing, hindi, duration, outage, aliasing, manoeuvres, freeing, discern,
# Nearest to articles: xenophanes, history, preoccupation, drawing, onomatopoeic, brooke, online, omission,
# Nearest to writers: births, herz, acs, publisher, legacy, bias, presentational, toasted,
# Nearest to pre: pacifistic, albeniz, expansion, dnieper, unction, norse, pyrimidines, kai,
# Nearest to smith: discography, isis, salaries, ludovic, tries, erlanger, chicagoland, templars,
# Nearest to applications: equine, systems, research, planning, enable, scan, microsystems, mpeg,
# Nearest to proposed: finances, compulsory, mlas, demonstrably, combats, austronesian, newsreader, folding,
# Nearest to hold: carmakers, remorse, whiteness, canoes, concealment, intricacy, unaccustomed, retailers,
# Nearest to event: pla, praetorian, conscious, camel, yamasaki, chretien, cin, relocating,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2915 0.0181 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3065 0.0173 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3161 0.0077 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2574 0.0171 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2200 0.0171 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2291 0.0173 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2150 0.0170 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2085 0.0169 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2155 0.0170 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1651 0.0169 sec/batch
# Nearest to an: multiprogramming, the, a, sums, form, aneurin, duels, monarch,
# Nearest to with: shine, arrhenius, warlordism, becker, rechargeable, linebarger, determines, bookmarks,
# Nearest to more: beneficiaries, explores, tridentine, sensuality, daerah, bubbling, rollercoaster, stymied,
# Nearest to no: heir, dactyl, diligence, pair, aukrust, novice, reworkings, minute,
# Nearest to time: jiu, aware, pont, exit, intercept, heliopause, on, assurance,
# Nearest to would: circulation, must, comfortably, macy, lords, divorcing, nonterminals, ul,
# Nearest to by: silver, denumerable, surya, enveloping, pied, defeating, homonyms, starbuck,
# Nearest to this: manoeuvres, duration, hindi, soul, while, freeing, outage, decomposing,
# Nearest to articles: xenophanes, history, preoccupation, drawing, onomatopoeic, online, veneziano, omission,
# Nearest to writers: births, herz, acs, presentational, publisher, bias, toasted, legacy,
# Nearest to pre: pacifistic, dnieper, albeniz, kai, expansion, abounds, ceremoniously, unction,
# Nearest to smith: discography, isis, ludovic, salaries, erlanger, tries, hyrum, chicagoland,
# Nearest to applications: research, equine, scan, apple, planning, microsystems, systems, mpeg,
# Nearest to proposed: mlas, compulsory, demonstrably, phased, cerebellar, newsreader, austronesian, combats,
# Nearest to hold: carmakers, remorse, whiteness, concealment, unaccustomed, retailers, policemen, intricacy,
# Nearest to event: pla, praetorian, camel, conscious, yamasaki, cin, chretien, relocating,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2653 0.0180 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2132 0.0171 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1997 0.0170 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1191 0.0170 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1658 0.0170 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1543 0.0171 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1647 0.0170 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1919 0.0171 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2161 0.0172 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1535 0.0171 sec/batch
# Nearest to an: the, a, multiprogramming, sums, form, sulfide, tension, morphism,
# Nearest to with: shine, becker, arrhenius, rechargeable, linebarger, bookmarks, lair, determines,
# Nearest to more: explores, beneficiaries, bubbling, daerah, thinner, rollercoaster, sensuality, stymied,
# Nearest to no: heir, dactyl, diligence, novice, reworkings, pair, aukrust, damned,
# Nearest to time: jiu, intercept, aware, on, pont, heliopause, exit, exceeded,
# Nearest to would: circulation, must, comfortably, lords, overbending, nonterminals, macy, conjectural,
# Nearest to by: enveloping, silver, surya, multi, denumerable, starbuck, airtime, theoretic,
# Nearest to this: soul, duration, hindi, aliasing, decomposing, concedes, manoeuvres, while,
# Nearest to articles: history, xenophanes, online, preoccupation, drawing, onomatopoeic, website, encyclopedia,
# Nearest to writers: births, herz, acs, presentational, publisher, toasted, bias, vivid,
# Nearest to pre: pacifistic, albeniz, dnieper, kai, expansion, unction, norse, ceremoniously,
# Nearest to smith: discography, ludovic, isis, tries, salaries, jet, templars, hyrum,
# Nearest to applications: research, equine, scan, planning, enable, editor, microsystems, systems,
# Nearest to proposed: demonstrably, mlas, cerebellar, newsreader, combats, austronesian, phased, finances,
# Nearest to hold: carmakers, concealment, remorse, intricacy, whiteness, canoes, retailers, bloodline,
# Nearest to event: pla, praetorian, camel, conscious, chretien, relocating, yamasaki, cin,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1745 0.0180 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2069 0.0171 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1672 0.0170 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1457 0.0171 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1727 0.0170 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1662 0.0168 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2094 0.0171 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1640 0.0169 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1443 0.0170 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1695 0.0170 sec/batch
# Nearest to an: a, the, multiprogramming, sums, monarch, form, duels, chestnut,
# Nearest to with: becker, shine, linebarger, overstated, arrhenius, determines, bookmarks, lair,
# Nearest to more: explores, bubbling, daerah, beneficiaries, scattered, tridentine, sensuality, stymied,
# Nearest to no: dactyl, heir, diligence, novice, continuity, reworkings, damned, aukrust,
# Nearest to time: jiu, intercept, aware, heliopause, pont, on, exit, receiver,
# Nearest to would: circulation, comfortably, must, lords, overbending, nonterminals, accountable, conjectural,
# Nearest to by: enveloping, theoretic, multi, denumerable, silver, aziz, weldon, the,
# Nearest to this: soul, decomposing, aliasing, duration, manoeuvres, hindi, while, outage,
# Nearest to articles: history, xenophanes, online, preoccupation, drawing, website, encyclopedia, collectible,
# Nearest to writers: births, acs, presentational, herz, publisher, toasted, bias, vivid,
# Nearest to pre: norse, unction, albeniz, ceremoniously, pacifistic, pyrimidines, partake, dnieper,
# Nearest to smith: ludovic, discography, salaries, tries, isis, jet, templars, monkees,
# Nearest to applications: research, planning, scan, equine, editor, systems, microsystems, commerce,
# Nearest to proposed: mlas, compulsory, newsreader, demonstrably, cerebellar, combats, phased, censure,
# Nearest to hold: carmakers, concealment, intricacy, remorse, whiteness, retailers, devolved, canoes,
# Nearest to event: pla, praetorian, conscious, camel, chretien, yamasaki, relocating, mdf,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1873 0.0180 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1569 0.0170 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1758 0.0169 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1785 0.0171 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1338 0.0170 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1492 0.0171 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1783 0.0170 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1234 0.0170 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1673 0.0169 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1955 0.0170 sec/batch
# Nearest to an: a, the, multiprogramming, monarch, sums, juxtaposed, duels, kanda,
# Nearest to with: becker, shine, warlordism, movie, overstated, arrhenius, linebarger, bookmarks,
# Nearest to more: explores, bubbling, daerah, sensuality, beneficiaries, communism, stymied, tridentine,
# Nearest to no: heir, dactyl, diligence, damned, aukrust, novice, reworkings, posed,
# Nearest to time: jiu, hispania, pont, aware, intercept, heliopause, exceeded, torturing,
# Nearest to would: circulation, lords, accountable, comfortably, must, macy, triggering, karzai,
# Nearest to by: the, multi, weldon, silver, aziz, enveloping, defeating, jacob,
# Nearest to this: manoeuvres, duration, decomposing, soul, concedes, while, trainspotting, aliasing,
# Nearest to articles: history, xenophanes, online, preoccupation, drawing, website, highlanders, collectible,
# Nearest to writers: births, herz, presentational, acs, publisher, toasted, people, entertainers,
# Nearest to pre: dnieper, norse, albeniz, ceremoniously, pacifistic, expansion, unction, raged,
# Nearest to smith: ludovic, discography, possibility, salaries, tries, isis, hyrum, anglophone,
# Nearest to applications: research, scan, equine, systems, microsystems, editor, planning, commerce,
# Nearest to proposed: compulsory, mlas, combats, demonstrably, phased, cerebellar, newsreader, finances,
# Nearest to hold: carmakers, intricacy, whiteness, concealment, devolved, confessed, canoes, makeover,
# Nearest to event: pla, conscious, praetorian, camel, chretien, relocating, cin, yamasaki,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2328 0.0179 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1331 0.0168 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1438 0.0167 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1698 0.0169 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0248 0.0174 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1346 0.0176 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1483 0.0174 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1489 0.0176 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1537 0.0030 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1207 0.0176 sec/batch
# Nearest to an: a, the, multiprogramming, sums, form, juxtaposed, quaternions, aneurin,
# Nearest to with: shine, becker, arrhenius, bookmarks, linebarger, warlordism, rechargeable, overstated,
# Nearest to more: explores, stymied, daerah, beneficiaries, bubbling, communism, unskilled, thinner,
# Nearest to no: heir, dactyl, diligence, novice, damned, married, minute, posed,
# Nearest to time: jiu, intercept, aware, exceeded, pont, exit, receiver, heliopause,
# Nearest to would: circulation, lords, comfortably, nonterminals, accountable, macy, praised, weakness,
# Nearest to by: multi, silver, the, denumerable, airtime, defeating, arpanet, enveloping,
# Nearest to this: aliasing, soul, decomposing, duration, pq, while, concedes, trainspotting,
# Nearest to articles: history, xenophanes, online, website, collectible, highlanders, preoccupation, encyclopedia,
# Nearest to writers: births, herz, presentational, acs, bias, toasted, entertainers, people,
# Nearest to pre: expansion, albeniz, dnieper, pacifistic, norse, vocabulary, ceremoniously, pyrimidines,
# Nearest to smith: ludovic, discography, tries, salaries, possibility, jet, isis, erlanger,
# Nearest to applications: research, equine, scan, microsystems, systems, planning, editor, tools,
# Nearest to proposed: mlas, phased, compulsory, cerebellar, newsreader, austronesian, combats, demonstrably,
# Nearest to hold: carmakers, intricacy, retailers, concealment, canoes, devolved, whiteness, astonished,
# Nearest to event: pla, praetorian, conscious, camel, chretien, cin, yamasaki, relocating,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0898 0.0181 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0593 0.0169 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0972 0.0169 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0460 0.0172 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0521 0.0168 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0609 0.0169 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0734 0.0170 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1198 0.0170 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1362 0.0171 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0158 0.0173 sec/batch
# Nearest to an: a, the, multiprogramming, sums, form, chestnut, tension, serendip,
# Nearest to with: becker, arrhenius, shine, determines, freezing, rechargeable, bookmarks, linebarger,
# Nearest to more: unskilled, beneficiaries, rollercoaster, thinner, stymied, explores, become, daerah,
# Nearest to no: heir, novice, diligence, dactyl, married, damned, charioteer, minute,
# Nearest to time: jiu, intercept, on, exceeded, receiver, heliopause, aware, revue,
# Nearest to would: circulation, nonterminals, comfortably, lords, accountable, sprayed, must, icosidodecahedron,
# Nearest to by: the, silver, multi, arpanet, defeating, airtime, aziz, enveloping,
# Nearest to this: soul, duration, while, aliasing, concedes, trainspotting, crawler, decomposing,
# Nearest to articles: xenophanes, history, online, website, collectible, highlanders, encyclopedia, preoccupation,
# Nearest to writers: births, herz, acs, bias, presentational, people, entertainers, toasted,
# Nearest to pre: dnieper, expansion, pacifistic, albeniz, raged, abounds, ceremoniously, norse,
# Nearest to smith: ludovic, salaries, discography, tries, jet, possibility, vx, hyrum,
# Nearest to applications: research, scan, equine, editor, planning, microsystems, systems, commerce,
# Nearest to proposed: mlas, phased, newsreader, combats, compulsory, demonstrably, cerebellar, austronesian,
# Nearest to hold: carmakers, retailers, intricacy, devolved, concealment, cabinets, astonished, unaccustomed,
# Nearest to event: pla, praetorian, camel, chretien, cin, conscious, yamasaki, relocating,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0348 0.0179 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0034 0.0168 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0266 0.0168 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0676 0.0168 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0699 0.0170 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0392 0.0170 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0797 0.0169 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1297 0.0170 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0948 0.0170 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0206 0.0170 sec/batch
# Nearest to an: a, the, form, multiprogramming, sums, quaternions, are, particularism,
# Nearest to with: becker, shine, arrhenius, overstated, rechargeable, determines, bookmarks, movie,
# Nearest to more: explores, bubbling, become, rollercoaster, beneficiaries, stymied, thinner, unskilled,
# Nearest to no: heir, novice, dactyl, diligence, damned, married, pair, minute,
# Nearest to time: on, intercept, jiu, exceeded, heliopause, aware, pont, epoch,
# Nearest to would: circulation, accountable, comfortably, nonterminals, must, directives, lords, overbending,
# Nearest to by: the, multi, enveloping, theoretic, keynes, arpanet, silver, aziz,
# Nearest to this: soul, aliasing, trainspotting, duration, crawler, while, concedes, only,
# Nearest to articles: history, xenophanes, online, collectible, website, encyclopedia, drawing, preoccupation,
# Nearest to writers: births, bias, presentational, herz, acs, people, dramatists, entertainers,
# Nearest to pre: expansion, dnieper, pacifistic, albeniz, pyrimidines, raged, norse, vocabulary,
# Nearest to smith: ludovic, tries, salaries, jet, discography, vx, natura, possibility,
# Nearest to applications: research, scan, equine, planning, systems, commerce, editor, filesystems,
# Nearest to proposed: mlas, combats, newsreader, cerebellar, demonstrably, phased, biomes, everglades,
# Nearest to hold: carmakers, intricacy, retailers, devolved, cabinets, concealment, canoes, astonished,
# Nearest to event: pla, camel, praetorian, chretien, conscious, relocating, cin, mdf,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0390 0.0180 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0899 0.0170 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0550 0.0169 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0383 0.0170 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0594 0.0170 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0412 0.0169 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0460 0.0168 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0532 0.0169 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1148 0.0168 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0723 0.0169 sec/batch
# Nearest to an: a, the, form, multiprogramming, sums, tension, monarch, chestnut,
# Nearest to with: becker, shine, overstated, arrhenius, warlordism, determines, freeciv, freezing,
# Nearest to more: explores, stymied, unskilled, bubbling, civilization, rollercoaster, tridentine, beneficiaries,
# Nearest to no: heir, dactyl, novice, damned, diligence, charioteer, married, continuity,
# Nearest to time: jiu, exceeded, hispania, on, intercept, heliopause, epoch, pont,
# Nearest to would: circulation, accountable, nonterminals, lords, comfortably, triggering, described, disgrace,
# Nearest to by: the, theoretic, multi, enveloping, weldon, silver, aziz, defeating,
# Nearest to this: soul, manoeuvres, unproductive, while, concedes, trainspotting, decomposing, variability,
# Nearest to articles: history, xenophanes, online, collectible, website, highlanders, drawing, encyclopedia,
# Nearest to writers: births, bias, presentational, herz, acs, publisher, entertainers, dramatists,
# Nearest to pre: expansion, dnieper, pyrimidines, albeniz, pacifistic, norse, vocabulary, raged,
# Nearest to smith: ludovic, tries, salaries, discography, jet, vx, feuerbach, natura,
# Nearest to applications: research, scan, equine, planning, editor, ruby, ccd, microsystems,
# Nearest to proposed: combats, mlas, newsreader, archontology, everglades, compulsory, demonstrably, phased,
# Nearest to hold: carmakers, intricacy, retailers, devolved, cabinets, bill, concealment, chatsworth,
# Nearest to event: pla, praetorian, camel, conscious, chretien, cin, yamasaki, contending,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0407 0.0177 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0058 0.0167 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0389 0.0167 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0534 0.0171 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0932 0.0177 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1321 0.0170 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1275 0.0170 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0410 0.0167 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0086 0.0168 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0465 0.0168 sec/batch
# Nearest to an: a, the, form, multiprogramming, sums, morphism, turns, juxtaposed,
# Nearest to with: becker, shine, overstated, quicken, and, arrhenius, freeciv, freezing,
# Nearest to more: explores, unskilled, bubbling, rollercoaster, tridentine, stymied, suites, sensuality,
# Nearest to no: dactyl, heir, damned, novice, diligence, aukrust, married, pair,
# Nearest to time: exceeded, intercept, jiu, hispania, on, heliopause, epoch, aware,
# Nearest to would: circulation, accountable, lords, nonterminals, karzai, triggering, comfortably, rampton,
# Nearest to by: the, multi, theoretic, silver, airtime, arpanet, weldon, enveloping,
# Nearest to this: aliasing, concedes, decomposing, soul, trainspotting, while, diversify, variability,
# Nearest to articles: history, online, xenophanes, collectible, website, drawing, highlanders, encyclopedia,
# Nearest to writers: births, acs, bias, entertainers, herz, people, dramatists, presentational,
# Nearest to pre: expansion, dnieper, vocabulary, pacifistic, norse, albeniz, pyrimidines, raged,
# Nearest to smith: ludovic, salaries, tries, jet, discography, vx, possibility, hyrum,
# Nearest to applications: research, equine, scan, planning, systems, microsystems, ccd, editor,
# Nearest to proposed: mlas, combats, newsreader, archontology, icsu, compulsory, cerebellar, phased,
# Nearest to hold: carmakers, intricacy, retailers, astonished, chatsworth, devolved, concealment, cabinets,
# Nearest to event: pla, camel, praetorian, conscious, cin, chretien, yamasaki, truthfully,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9827 0.0180 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0146 0.0170 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0326 0.0169 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0135 0.0174 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0754 0.0170 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0717 0.0151 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0239 0.0169 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9755 0.0171 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0184 0.0170 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9684 0.0167 sec/batch
# Nearest to an: the, a, form, multiprogramming, sums, quaternions, chestnut, turns,
# Nearest to with: becker, shine, and, rechargeable, freezing, overstated, bookmarks, evaporated,
# Nearest to more: explores, unskilled, stymied, tridentine, rollercoaster, bubbling, thinner, beneficiaries,
# Nearest to no: diligence, damned, heir, novice, married, dactyl, aukrust, charioteer,
# Nearest to time: exceeded, intercept, hispania, on, jiu, epoch, heliopause, pont,
# Nearest to would: circulation, accountable, comfortably, nonterminals, lords, triggering, icosidodecahedron, sprayed,
# Nearest to by: the, airtime, silver, multi, ems, arpanet, pied, defeating,
# Nearest to this: soul, trainspotting, hindi, concedes, crawler, decomposing, aliasing, only,
# Nearest to articles: history, xenophanes, collectible, online, website, qaida, highlanders, preoccupation,
# Nearest to writers: births, herz, bias, people, acs, presentational, dramatists, novelists,
# Nearest to pre: expansion, dnieper, vocabulary, pacifistic, pyrimidines, abounds, raged, albeniz,
# Nearest to smith: ludovic, tries, salaries, jet, natura, vx, discography, possibility,
# Nearest to applications: research, equine, scan, microsystems, ruby, systems, planning, ccd,
# Nearest to proposed: combats, mlas, demonstrably, newsreader, everglades, phased, surveyor, icsu,
# Nearest to hold: carmakers, intricacy, retailers, devolved, chatsworth, astonished, cabinets, concealment,
# Nearest to event: pla, praetorian, camel, cin, chretien, truthfully, conscious, contending,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0127 0.0178 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9471 0.0168 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0158 0.0167 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0037 0.0170 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9902 0.0170 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0097 0.0167 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9199 0.0169 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9713 0.0169 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9485 0.0170 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9549 0.0178 sec/batch
# Nearest to an: a, the, form, turns, chestnut, quaternions, multiprogramming, morphism,
# Nearest to with: becker, rechargeable, and, shine, freezing, determines, invariably, overstated,
# Nearest to more: unskilled, explores, become, stymied, rollercoaster, thinner, waffle, daerah,
# Nearest to no: damned, married, heir, diligence, novice, dactyl, them, pair,
# Nearest to time: intercept, exceeded, epoch, on, jiu, autographed, hispania, heliopause,
# Nearest to would: circulation, nonterminals, accountable, comfortably, triggering, karzai, must, lords,
# Nearest to by: the, airtime, multi, silver, defeating, arpanet, ems, pangolins,
# Nearest to this: soul, only, unproductive, concedes, crawler, while, trainspotting, hypoxic,
# Nearest to articles: history, collectible, xenophanes, online, website, qaida, highlanders, encyclopedia,
# Nearest to writers: births, bias, presentational, people, acs, dramatists, infringement, herz,
# Nearest to pre: expansion, dnieper, pacifistic, vocabulary, albeniz, pyrimidines, abounds, raged,
# Nearest to smith: ludovic, tries, salaries, possibility, natura, discography, jet, feuerbach,
# Nearest to applications: research, scan, equine, ccd, ruby, planning, populist, commerce,
# Nearest to proposed: mlas, combats, everglades, newsreader, cerebellar, icsu, demonstrably, phased,
# Nearest to hold: carmakers, intricacy, retailers, chatsworth, cabinets, devolved, astonished, bassett,
# Nearest to event: pla, praetorian, camel, chretien, relocating, cin, contending, observers,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9972 0.0181 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0105 0.0168 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9582 0.0168 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0095 0.0170 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0223 0.0171 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9850 0.0169 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9877 0.0169 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9858 0.0171 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9851 0.0169 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9909 0.0169 sec/batch
# Nearest to an: a, the, form, turns, shrouded, sums, philadelphia, quaternions,
# Nearest to with: becker, and, overstated, alice, shine, in, knightsbridge, the,
# Nearest to more: explores, tridentine, unskilled, rollercoaster, featured, somali, suites, domineering,
# Nearest to no: damned, diligence, novice, heir, dactyl, them, aukrust, married,
# Nearest to time: exceeded, epoch, on, intercept, hispania, autographed, ten, calculate,
# Nearest to would: circulation, nonterminals, accountable, comfortably, must, described, lords, kafir,
# Nearest to by: the, airtime, of, multi, theoretic, enveloping, called, arpanet,
# Nearest to this: the, soul, be, only, concedes, a, unproductive, is,
# Nearest to articles: history, online, collectible, website, xenophanes, encyclopedia, yahoo, profile,
# Nearest to writers: births, bias, presentational, dramatists, infringement, people, acs, herz,
# Nearest to pre: expansion, dnieper, pacifistic, vocabulary, albeniz, raged, pyrimidines, abounds,
# Nearest to smith: ludovic, tries, salaries, jet, discography, possibility, hyrum, feuerbach,
# Nearest to applications: research, systems, planning, scan, commerce, ruby, ccd, equine,
# Nearest to proposed: mlas, combats, everglades, biomes, cerebellar, newsreader, demonstrably, icsu,
# Nearest to hold: carmakers, intricacy, chatsworth, retailers, astonished, cabinets, devolved, celebrating,
# Nearest to event: pla, camel, praetorian, observers, sidereal, chretien, contending, truthfully,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0000 0.0178 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9660 0.0167 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9945 0.0168 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9944 0.0168 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9967 0.0167 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9840 0.0167 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9725 0.0167 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9467 0.0170 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9613 0.0171 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0268 0.0169 sec/batch
# Nearest to an: a, the, form, turns, multiprogramming, philadelphia, sums, donate,
# Nearest to with: becker, and, overstated, excommunications, in, the, quicken, shine,
# Nearest to more: explores, become, unskilled, stymied, tridentine, popularity, suites, decline,
# Nearest to no: damned, diligence, heir, novice, them, dactyl, aukrust, married,
# Nearest to time: exceeded, hispania, epoch, on, intercept, ten, calculate, however,
# Nearest to would: nonterminals, circulation, accountable, icosidodecahedron, triggering, comfortably, lords, described,
# Nearest to by: the, of, multi, for, arpanet, been, airtime, archontology,
# Nearest to this: hindi, only, the, concedes, soul, unproductive, a, trainspotting,
# ...
# Nearest to an: a, the, is, by, form, at, this, of,
# Nearest to with: and, in, a, the, becker, also, which, three,
# Nearest to more: than, ktv, become, considerably, such, undertones, because, subscalar,
# Nearest to no: damned, cerevisiae, diligence, together, deification, consecrate, novice, sahel,
# Nearest to time: epoch, likenesses, ten, hispania, however, measured, around, on,
# Nearest to would: not, abner, predicted, arrange, forced, nonterminals, did, accountable,
# Nearest to by: the, of, a, and, an, later, called, both,
# Nearest to this: the, a, of, is, an, in, be, called,
# Nearest to articles: history, online, article, collectible, xenophanes, homepage, website, listing,
# Nearest to writers: births, novelists, autodidacts, people, dramatists, satirists, poets, politicians,
# Nearest to pre: pyrimidines, gargoyles, early, expansion, albeniz, dnieper, raged, ambulatory,
# Nearest to smith: salaries, tries, ludovic, hyrum, scriptura, satyendra, cantona, manoa,
# Nearest to applications: application, systems, prevention, ccd, ruby, research, populist, trigonometry,
# Nearest to proposed: icsu, darwinian, relativity, biomes, mlas, fasciculata, adjudicate, combats,
# Nearest to hold: carmakers, retailers, accountancy, rests, kp, intricacy, celebrating, bulmer,
# Nearest to event: sidereal, weekend, extinction, tens, celebrating, camel, observers, customizable,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8322 0.0175 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8433 0.0164 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8315 0.0168 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8383 0.0168 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8708 0.0166 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8788 0.0171 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8504 0.0168 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8302 0.0168 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8806 0.0168 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8528 0.0166 sec/batch
# Nearest to an: the, a, by, and, philadelphia, was, at, form,
# Nearest to with: and, in, the, also, a, excommunications, becker, which,
# Nearest to more: than, ktv, become, already, considerably, three, rollercoaster, from,
# Nearest to no: damned, diligence, deification, novice, cerevisiae, consecrate, them, sahel,
# Nearest to time: epoch, likenesses, ten, hispania, however, the, around, was,
# Nearest to would: not, nonterminals, accountable, unexpired, eagerly, did, predicted, lexikon,
# Nearest to by: the, of, and, a, an, both, in, into,
# Nearest to this: the, a, of, is, be, called, an, it,
# Nearest to articles: history, online, article, collectible, xenophanes, website, listing, bollingen,
# Nearest to writers: births, autodidacts, novelists, poets, fiction, people, dramatists, satirists,
# Nearest to pre: pyrimidines, gargoyles, early, dnieper, albeniz, expansion, monera, ambulatory,
# Nearest to smith: salaries, tries, ludovic, satyendra, scriptura, hyrum, cantona, manoa,
# Nearest to applications: application, prevention, ccd, systems, ruby, research, ferromagnetic, mcmurray,
# Nearest to proposed: darwinian, icsu, mlas, relativity, adjudicate, biomes, fasciculata, combats,
# Nearest to hold: carmakers, retailers, rests, accountancy, celebrating, all, kp, intricacy,
# Nearest to event: sidereal, extinction, observers, celebrating, weekend, tens, celebrated, duration,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8431 0.0176 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8617 0.0167 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8118 0.0168 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8231 0.0168 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8986 0.0170 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8288 0.0167 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9435 0.0167 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8884 0.0167 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9368 0.0167 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8495 0.0167 sec/batch
# Nearest to an: a, the, by, philadelphia, at, and, is, was,
# Nearest to with: and, in, the, also, which, a, excommunications, continued,
# Nearest to more: than, ktv, considerably, from, million, become, undertones, rollercoaster,
# Nearest to no: damned, deification, diligence, cerevisiae, consecrate, them, loves, novice,
# Nearest to time: epoch, ten, likenesses, however, hispania, captivity, was, on,
# Nearest to would: not, nonterminals, predicted, unexpired, likely, forced, did, accountable,
# Nearest to by: the, of, and, later, a, for, an, on,
# Nearest to this: a, the, is, be, of, an, it, july,
# Nearest to articles: history, online, article, collectible, xenophanes, flickr, bloody, bollingen,
# Nearest to writers: births, autodidacts, novelists, people, poets, dramatists, fiction, politicians,
# Nearest to pre: pyrimidines, gargoyles, expansion, albeniz, raged, dnieper, monera, early,
# Nearest to smith: salaries, ludovic, tries, scriptura, hyrum, satyendra, cantona, loss,
# Nearest to applications: application, systems, prevention, ccd, ruby, aware, research, populist,
# Nearest to proposed: mlas, icsu, darwinian, relativity, adjudicate, combats, findings, fasciculata,
# Nearest to hold: carmakers, retailers, accountancy, celebrating, rests, bulmer, all, shoguns,
# Nearest to event: sidereal, extinction, weekend, observers, celebrating, tens, camel, celebrated,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7717 0.0175 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8482 0.0165 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7656 0.0167 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8925 0.0168 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8582 0.0165 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8509 0.0166 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9174 0.0081 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8193 0.0166 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8266 0.0167 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8410 0.0166 sec/batch
# Nearest to an: the, a, by, is, and, philadelphia, at, as,
# Nearest to with: and, in, the, a, excommunications, also, which, by,
# Nearest to more: than, ktv, undertones, considerably, become, already, scotsman, rollercoaster,
# Nearest to no: damned, diligence, cerevisiae, deification, sahel, consecrate, novice, them,
# Nearest to time: epoch, likenesses, ten, hispania, however, was, deletion, aware,
# Nearest to would: not, nonterminals, predicted, another, abner, icosidodecahedron, unexpired, personal,
# Nearest to by: the, of, a, and, an, later, for, into,
# Nearest to this: the, a, is, be, an, it, july, of,
# Nearest to articles: history, article, online, collectible, xenophanes, flickr, bollingen, blogs,
# Nearest to writers: births, people, autodidacts, novelists, poets, dramatists, fiction, satirists,
# Nearest to pre: expansion, pyrimidines, gargoyles, albeniz, dnieper, shamanism, early, monera,
# Nearest to smith: salaries, tries, ludovic, hyrum, scriptura, satyendra, marks, cantona,
# Nearest to applications: application, ruby, ccd, systems, prevention, populist, aware, research,
# Nearest to proposed: relativity, mlas, icsu, adjudicate, darwinian, phased, combats, dmg,
# Nearest to hold: carmakers, retailers, rests, bulmer, accountancy, all, celebrating, shoguns,
# Nearest to event: sidereal, extinction, weekend, celebrating, camel, tens, duration, federation,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8377 0.0175 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8477 0.0168 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8379 0.0166 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7871 0.0166 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8601 0.0167 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8442 0.0168 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8482 0.0167 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7670 0.0167 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8297 0.0167 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8172 0.0165 sec/batch
# Nearest to an: a, the, is, by, and, as, in, at,
# Nearest to with: and, in, the, also, a, which, by, excommunications,
# Nearest to more: than, because, already, other, considerably, are, three, become,
# Nearest to no: damned, deification, cerevisiae, diligence, them, together, consecrate, mayen,
# Nearest to time: epoch, likenesses, however, called, this, deletion, ten, hispania,
# Nearest to would: not, nonterminals, that, another, unexpired, did, icosidodecahedron, abner,
# Nearest to by: the, of, a, and, an, into, for, both,
# Nearest to this: the, a, of, is, be, in, called, which,
# Nearest to articles: history, article, online, collectible, xenophanes, hauck, flickr, listing,
# Nearest to writers: births, autodidacts, people, novelists, fiction, satirists, poets, dramatists,
# Nearest to pre: pyrimidines, expansion, gargoyles, early, albeniz, monera, dnieper, eskimos,
# Nearest to smith: salaries, tries, ludovic, hyrum, loss, cantona, scriptura, satyendra,
# Nearest to applications: application, ccd, systems, ruby, prevention, populist, aware, trigonometry,
# Nearest to proposed: relativity, mlas, darwinian, icsu, phased, adjudicate, biomes, combats,
# Nearest to hold: carmakers, retailers, rests, celebrating, accountancy, all, bulmer, disallows,
# Nearest to event: sidereal, celebrating, extinction, weekend, federation, celebrated, tens, camel,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7698 0.0175 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8212 0.0169 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8570 0.0166 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8296 0.0169 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7952 0.0167 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8634 0.0166 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8359 0.0167 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8147 0.0168 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8211 0.0166 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8365 0.0167 sec/batch
# Nearest to an: a, the, by, and, is, in, as, philadelphia,
# Nearest to with: and, in, a, the, also, by, which, of,
# Nearest to more: than, three, because, already, ktv, eight, are, seven,
# Nearest to no: deification, damned, diligence, together, cerevisiae, dactyl, consecrate, buckskin,
# Nearest to time: epoch, called, likenesses, measured, ten, deletion, however, around,
# Nearest to would: not, that, predicted, nonterminals, eagerly, unexpired, another, did,
# Nearest to by: the, a, of, and, an, in, for, both,
# Nearest to this: the, a, is, be, of, called, in, that,
# Nearest to articles: history, article, online, collectible, messageboard, bollingen, listing, searches,
# Nearest to writers: births, autodidacts, people, poets, novelists, fiction, satirists, dramatists,
# Nearest to pre: pyrimidines, expansion, gargoyles, early, albeniz, kahului, ambulatory, monera,
# Nearest to smith: salaries, tries, ludovic, hyrum, loss, scriptura, cantona, marks,
# Nearest to applications: application, systems, ccd, ruby, trigonometry, prevention, populist, research,
# Nearest to proposed: mlas, relativity, darwinian, adjudicate, icsu, phased, combats, fasciculata,
# Nearest to hold: carmakers, rests, retailers, celebrating, all, accountancy, bulmer, kp,
# Nearest to event: sidereal, extinction, celebrating, weekend, tens, emitted, observers, duration,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9028 0.0179 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8137 0.0170 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8015 0.0169 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8346 0.0168 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8729 0.0168 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8423 0.0168 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8313 0.0167 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8491 0.0169 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8277 0.0167 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8237 0.0167 sec/batch
# Nearest to an: a, the, is, by, in, and, at, of,
# Nearest to with: and, in, the, a, which, by, of, also,
# Nearest to more: than, three, because, other, already, are, one, eight,
# Nearest to no: deification, cerevisiae, did, diligence, import, consecrate, damned, together,
# Nearest to time: epoch, ten, likenesses, called, however, deletion, hispania, measured,
# Nearest to would: not, nonterminals, that, did, to, unexpired, icosidodecahedron, but,
# Nearest to by: the, of, a, and, for, an, in, into,
# Nearest to this: the, a, is, of, be, in, for, an,
# Nearest to articles: history, article, online, collectible, listing, messageboard, rants, lobbied,
# Nearest to writers: births, autodidacts, fiction, novelists, poets, people, satirists, dramatists,
# Nearest to pre: early, pyrimidines, gargoyles, expansion, kahului, albeniz, raged, shamanism,
# Nearest to smith: salaries, tries, ludovic, hyrum, scriptura, cantona, loss, satyendra,
# Nearest to applications: application, systems, ccd, ruby, research, prevention, trigonometry, mcmurray,
# Nearest to proposed: mlas, darwinian, adjudicate, relativity, dmg, phased, icsu, biomes,
# Nearest to hold: carmakers, rests, retailers, celebrating, bulmer, accountancy, disallows, all,
# Nearest to event: sidereal, extinction, weekend, celebrating, duration, unfilled, observers, tens,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8607 0.0175 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8116 0.0167 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9000 0.0167 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9163 0.0166 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8988 0.0166 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8366 0.0168 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7897 0.0165 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8023 0.0165 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7408 0.0166 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8573 0.0166 sec/batch
# Nearest to an: a, the, by, is, and, as, was, in,
# Nearest to with: and, in, the, also, a, which, by, of,
# Nearest to more: than, because, is, other, are, some, undertones, ktv,
# Nearest to no: deification, cerevisiae, diligence, damned, import, consecrate, buckskin, together,
# Nearest to time: epoch, deletion, likenesses, ten, however, measured, was, called,
# Nearest to would: not, nonterminals, that, another, unexpired, did, predicted, to,
# Nearest to by: the, of, a, an, and, for, on, into,
# Nearest to this: the, a, is, of, be, for, an, called,
# Nearest to articles: online, article, history, collectible, messageboard, rants, orsz, blogs,
# Nearest to writers: births, people, novelists, autodidacts, poets, fiction, satirists, bias,
# Nearest to pre: pyrimidines, gargoyles, expansion, early, monera, reboot, albeniz, shamanism,
# Nearest to smith: salaries, tries, ludovic, hyrum, scriptura, cantona, loss, marks,
# Nearest to applications: application, systems, ccd, ruby, aware, business, mcmurray, trigonometry,
# Nearest to proposed: mlas, relativity, adjudicate, darwinian, dmg, icsu, fasciculata, phased,
# Nearest to hold: carmakers, rests, retailers, bulmer, accountancy, duluth, celebrating, kp,
# Nearest to event: weekend, celebrating, sidereal, extinction, camel, unfilled, celebrated, federation,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8287 0.0178 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8360 0.0167 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
